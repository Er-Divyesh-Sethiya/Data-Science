# %% [markdown]
# # Chapter 1 - Getting and Knowing your data

# %%
import pandas as pd

# %%
order_details = pd.read_csv('data.tsv.txt',sep = '\t')
order_details
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### 1.1 Perform Initial Analysis

# %%
order_details.head(n= 30)
# Out:
#     order_id  quantity                              item_name  \
# 0          1         1           Chips and Fresh Tomato Salsa
# 1          1         1                                   Izze
# 2          1         1                       Nantucket Nectar
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# 5          3         1                           Chicken Bowl
# 6          3         1                          Side of Chips
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 9          5         1                          Steak Burrito
# 10         5         1                    Chips and Guacamole
# 11         6         1                   Chicken Crispy Tacos
# 12         6         1                     Chicken Soft Tacos
# 13         7         1                           Chicken Bowl
# ...

# %%
order_details.tail(20)
# Out:
#       order_id  quantity            item_name  \
# 4602      1827         1     Barbacoa Burrito
# 4603      1827         1     Barbacoa Burrito
# 4604      1828         1         Chicken Bowl
# 4605      1828         1  Chips and Guacamole
# 4606      1828         1    Canned Soft Drink
# 4607      1829         1        Steak Burrito
# 4608      1829         1       Veggie Burrito
# 4609      1829         1    Canned Soft Drink
# 4610      1830         1        Steak Burrito
# 4611      1830         1       Veggie Burrito
# 4612      1831         1        Carnitas Bowl
# 4613      1831         1                Chips
# 4614      1831         1        Bottled Water
# 4615      1832         1   Chicken Soft Tacos
# 4616      1832         1  Chips and Guacamole
# 4617      1833         1        Steak Burrito
# 4618      1833         1        Steak Burrito
# 4619      1834         1   Chicken Salad Bowl
# 4620      1834         1   Chicken Salad Bowl
# ...

# %%
order_details.shape #Attribute
# Out:
# (4622, 5)

# %% [markdown]
# ### TERMINOLOGY ALERT
#
# * Rows - Observations/Records/Data points.
# * Columns - Features/Parameters.

# %%
order_details.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
order_details.describe(include='all')
# Out:
#            order_id     quantity     item_name choice_description item_price
# count   4622.000000  4622.000000          4622               3376       4622
# unique          NaN          NaN            50               1043         78
# top             NaN          NaN  Chicken Bowl        [Diet Coke]     $8.75
# freq            NaN          NaN           726                134        730
# mean     927.254868     1.075725           NaN                NaN        NaN
# std      528.890796     0.410186           NaN                NaN        NaN
# min        1.000000     1.000000           NaN                NaN        NaN
# 25%      477.250000     1.000000           NaN                NaN        NaN
# 50%      926.000000     1.000000           NaN                NaN        NaN
# 75%     1393.000000     1.000000           NaN                NaN        NaN
# max     1834.000000    15.000000           NaN                NaN        NaN

# %%
order_details.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
order_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %% [markdown]
# ## 1.2 Which item has been ordered most? Give me the top 5.

# %%
order_details.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
order_details.groupby(by='item_name')['quantity'].sum().sort_values(ascending=False).head() #Chain Methods
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Steak Burrito          386
# Canned Soft Drink      351
# Name: quantity, dtype: int64

# %%
order_details.groupby(by='item_name')['quantity'].sum().sort_values(ascending=False).tail(10)
# Out:
# item_name
# Burrito                              6
# Veggie Salad                         6
# Carnitas Salad Bowl                  6
# Bowl                                 4
# Steak Salad                          4
# Salad                                2
# Crispy Tacos                         2
# Chips and Mild Fresh Tomato Salsa    1
# Carnitas Salad                       1
# Veggie Crispy Tacos                  1
# Name: quantity, dtype: int64

# %% [markdown]
# # Chapter 2 - Filtering and Sorting

# %%
euro_2012 = pd.read_csv('Euro_2012_stats_TEAM.csv')
euro_2012
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
pd.set_option('max_columns',None) #No restriction in displaying the columns
#pd.set_option('max_rows',None)

# %%
euro_2012
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
euro_2012.columns
# Out:
# Index(['Team', 'Goals', 'Shots on target', 'Shots off target',
#        'Shooting Accuracy', '% Goals-to-shots', 'Total shots (inc. Blocked)',
#        'Hit Woodwork', 'Penalty goals', 'Penalties not scored', 'Headed goals',
#        'Passes', 'Passes completed', 'Passing Accuracy', 'Touches', 'Crosses',
#        'Dribbles', 'Corners Taken', 'Tackles', 'Clearances', 'Interceptions',
#        'Clearances off line', 'Clean Sheets', 'Blocks', 'Goals conceded',
#        'Saves made', 'Saves-to-shots ratio', 'Fouls Won', 'Fouls Conceded',
#        'Offsides', 'Yellow Cards', 'Red Cards', 'Subs on', 'Subs off',
#        'Players Used'],
#       dtype='object')

# %%
filtered_data = euro_2012[['Team','Shooting Accuracy','Yellow Cards','Red Cards']]
filtered_data
# Out:
#                    Team Shooting Accuracy  Yellow Cards  Red Cards
# 0               Croatia             51.9%             9          0
# 1        Czech Republic             41.9%             7          0
# 2               Denmark             50.0%             4          0
# 3               England             50.0%             5          0
# 4                France             37.9%             6          0
# 5               Germany             47.8%             4          0
# 6                Greece             30.7%             9          1
# 7                 Italy             43.0%            16          0
# 8           Netherlands             25.0%             5          0
# 9                Poland             39.4%             7          1
# 10             Portugal             34.3%            12          0
# 11  Republic of Ireland             36.8%             6          1
# 12               Russia             22.5%             6          0
# ...

# %%
filtered_data.sort_values(by = ['Yellow Cards'],ascending=False)
# Out:
#                    Team Shooting Accuracy  Yellow Cards  Red Cards
# 7                 Italy             43.0%            16          0
# 10             Portugal             34.3%            12          0
# 13                Spain             55.9%            11          0
# 0               Croatia             51.9%             9          0
# 6                Greece             30.7%             9          1
# 1        Czech Republic             41.9%             7          0
# 9                Poland             39.4%             7          1
# 14               Sweden             47.2%             7          0
# 4                France             37.9%             6          0
# 11  Republic of Ireland             36.8%             6          1
# 12               Russia             22.5%             6          0
# 3               England             50.0%             5          0
# 8           Netherlands             25.0%             5          0
# ...

# %%
filtered_data
# Out:
#                    Team Shooting Accuracy  Yellow Cards  Red Cards
# 0               Croatia             51.9%             9          0
# 1        Czech Republic             41.9%             7          0
# 2               Denmark             50.0%             4          0
# 3               England             50.0%             5          0
# 4                France             37.9%             6          0
# 5               Germany             47.8%             4          0
# 6                Greece             30.7%             9          1
# 7                 Italy             43.0%            16          0
# 8           Netherlands             25.0%             5          0
# 9                Poland             39.4%             7          1
# 10             Portugal             34.3%            12          0
# 11  Republic of Ireland             36.8%             6          1
# 12               Russia             22.5%             6          0
# ...

# %%
filtered_data[filtered_data['Team'] == 'Croatia']
# Out:
#       Team Shooting Accuracy  Yellow Cards  Red Cards
# 0  Croatia             51.9%             9          0

# %%
filtered_data[filtered_data['Red Cards'] == 1]
# Out:
#                    Team Shooting Accuracy  Yellow Cards  Red Cards
# 6                Greece             30.7%             9          1
# 9                Poland             39.4%             7          1
# 11  Republic of Ireland             36.8%             6          1

# %%
filtered_data[filtered_data['Red Cards'] == 1]
# Out:
#                    Team Shooting Accuracy  Yellow Cards  Red Cards
# 6                Greece             30.7%             9          1
# 9                Poland             39.4%             7          1
# 11  Republic of Ireland             36.8%             6          1

# %%
filtered_data = filtered_data.sort_values( by = 'Yellow Cards',ascending=False)

# %%
filtered_data
# Out:
#                    Team Shooting Accuracy  Yellow Cards  Red Cards
# 7                 Italy             43.0%            16          0
# 10             Portugal             34.3%            12          0
# 13                Spain             55.9%            11          0
# 0               Croatia             51.9%             9          0
# 6                Greece             30.7%             9          1
# 1        Czech Republic             41.9%             7          0
# 9                Poland             39.4%             7          1
# 14               Sweden             47.2%             7          0
# 4                France             37.9%             6          0
# 11  Republic of Ireland             36.8%             6          1
# 12               Russia             22.5%             6          0
# 3               England             50.0%             5          0
# 8           Netherlands             25.0%             5          0
# ...

# %%
filtered_data = euro_2012[['Team','Shooting Accuracy','Yellow Cards','Red Cards']]
filtered_data
# Out:
#                    Team Shooting Accuracy  Yellow Cards  Red Cards
# 0               Croatia             51.9%             9          0
# 1        Czech Republic             41.9%             7          0
# 2               Denmark             50.0%             4          0
# 3               England             50.0%             5          0
# 4                France             37.9%             6          0
# 5               Germany             47.8%             4          0
# 6                Greece             30.7%             9          1
# 7                 Italy             43.0%            16          0
# 8           Netherlands             25.0%             5          0
# 9                Poland             39.4%             7          1
# 10             Portugal             34.3%            12          0
# 11  Republic of Ireland             36.8%             6          1
# 12               Russia             22.5%             6          0
# ...

# %%
import warnings
warnings.filterwarnings(action = 'ignore')

# %%
filtered_data.sort_values(by = 'Yellow Cards',ascending=False,inplace=True) #Impact the original data

# %%
filtered_data
# Out:
#                    Team Shooting Accuracy  Yellow Cards  Red Cards
# 7                 Italy             43.0%            16          0
# 10             Portugal             34.3%            12          0
# 13                Spain             55.9%            11          0
# 0               Croatia             51.9%             9          0
# 6                Greece             30.7%             9          1
# 1        Czech Republic             41.9%             7          0
# 9                Poland             39.4%             7          1
# 14               Sweden             47.2%             7          0
# 4                France             37.9%             6          0
# 11  Republic of Ireland             36.8%             6          1
# 12               Russia             22.5%             6          0
# 3               England             50.0%             5          0
# 8           Netherlands             25.0%             5          0
# ...

# %%
filtered_data[(filtered_data['Yellow Cards'] > 9) | (filtered_data['Red Cards'] == 1)]
# Out:
#                    Team Shooting Accuracy  Yellow Cards  Red Cards
# 7                 Italy             43.0%            16          0
# 10             Portugal             34.3%            12          0
# 13                Spain             55.9%            11          0
# 6                Greece             30.7%             9          1
# 9                Poland             39.4%             7          1
# 11  Republic of Ireland             36.8%             6          1

# %% [markdown]
# ## EXPLORE - Query function

# %%
filtered_data.query()

# %% [markdown]
# ## ========================================================================

# %% [markdown]
# # Chapter 3 - Indexing

# %%
euro_2012
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ### 3.1 Get first 5 observations and first 5 features.

# %%
euro_2012.iloc[:5,:5]
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%

# %%
euro_2012.iloc[2:8,1:4]
# Out:
#    Goals  Shots on target  Shots off target
# 2      4               10                10
# 3      5               11                18
# 4      3               22                24
# 5     10               32                32
# 6      5                8                18
# 7      6               34                45

# %%
euro_2012.iloc[[0,2,3],[7,9]]
# Out:
#    Hit Woodwork  Penalties not scored
# 0             0                     0
# 2             1                     0
# 3             0                     0

# %%
euro_2012.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Team                        16 non-null     object
#  1   Goals                       16 non-null     int64
#  2   Shots on target             16 non-null     int64
#  3   Shots off target            16 non-null     int64
#  4   Shooting Accuracy           16 non-null     object
#  5   % Goals-to-shots            16 non-null     object
#  6   Total shots (inc. Blocked)  16 non-null     int64
#  7   Hit Woodwork                16 non-null     int64
#  8   Penalty goals               16 non-null     int64
#  9   Penalties not scored        16 non-null     int64
#  10  Headed goals                16 non-null     int64
#  11  Passes                      16 non-null     int64
#  12  Passes completed            16 non-null     int64
# ...

# %%
euro_2012.loc[:5,['Team','Red Cards']]
# Out:
#              Team  Red Cards
# 0         Croatia          0
# 1  Czech Republic          0
# 2         Denmark          0
# 3         England          0
# 4          France          0
# 5         Germany          0

# %%
euro_2012.loc[:5,['Team','Red Cards']]
# Out:
#              Team  Red Cards
# 0         Croatia          0
# 1  Czech Republic          0
# 2         Denmark          0
# 3         England          0
# 4          France          0
# 5         Germany          0

# %%
euro_2012
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
euro_2012.shape
# Out:
# (16, 35)

# %%
euro_2012.set_index(keys = 'Team',inplace=True)

# %%
euro_2012
# Out:
#                      Goals  Shots on target  Shots off target  \
# Team
# Croatia                  4               13                12
# Czech Republic           4               13                18
# Denmark                  4               10                10
# England                  5               11                18
# France                   3               22                24
# Germany                 10               32                32
# Greece                   5                8                18
# Italy                    6               34                45
# Netherlands              2               12                36
# Poland                   2               15                23
# Portugal                 6               22                42
# Republic of Ireland      1                7                12
# Russia                   5                9                31
# Spain                   12               42                33
# ...

# %%
euro_2012.shape
# Out:
# (16, 34)

# %%
euro_2012.loc[['Croatia','Denmark'],:]
# Out:
#          Goals  Shots on target  Shots off target Shooting Accuracy  \
# Team
# Croatia      4               13                12             51.9%
# Denmark      4               10                10             50.0%
#
#         % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  \
# Team
# Croatia            16.0%                          32             0
# Denmark            20.0%                          27             1
#
#          Penalty goals  Penalties not scored  Headed goals  Passes  \
# Team
# Croatia              0                     0             2    1076
# Denmark              0                     0             3    1298
#
#          Passes completed Passing Accuracy  Touches  Crosses  Dribbles  \
# Team
# Croatia               828            76.9%     1706       60        42
# Denmark              1082            83.3%     1873       43        32
#
#          Corners Taken  Tackles  Clearances  Interceptions  \
# Team
# ...

# %% [markdown]
# ## ========================================================================

# %% [markdown]
# # Chapter 4 - Delete

# %%
euro_2012 = pd.read_csv('Euro_2012_stats_TEAM.csv')
euro_2012
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
del euro_2012['Shooting Accuracy']

# %%
euro_2012
# Out:
#                      Goals  Shots on target  Shots off target  \
# Team
# Croatia                  4               13                12
# Czech Republic           4               13                18
# Denmark                  4               10                10
# England                  5               11                18
# France                   3               22                24
# Germany                 10               32                32
# Greece                   5                8                18
# Italy                    6               34                45
# Netherlands              2               12                36
# Poland                   2               15                23
# Portugal                 6               22                42
# Republic of Ireland      1                7                12
# Russia                   5                9                31
# Spain                   12               42                33
# ...

# %%
euro_2012.drop(labels = ['Hit Woodwork','Penalty goals'],axis=1,inplace=True)

# %%
euro_2012.drop('Goals',axis = 1,inplace=True)

# %%
euro_2012
# Out:
#                    Team  Shots on target  Shots off target Shooting Accuracy  \
# 0               Croatia               13                12             51.9%
# 1        Czech Republic               13                18             41.9%
# 2               Denmark               10                10             50.0%
# 3               England               11                18             50.0%
# 4                France               22                24             37.9%
# 5               Germany               32                32             47.8%
# 6                Greece                8                18             30.7%
# 7                 Italy               34                45             43.0%
# 8           Netherlands               12                36             25.0%
# 9                Poland               15                23             39.4%
# 10             Portugal               22                42             34.3%
# ...

# %%
euro_2012[['Team','Shots on target']]
# Out:
#                    Team  Shots on target
# 0               Croatia               13
# 1        Czech Republic               13
# 2               Denmark               10
# 3               England               11
# 4                France               22
# 5               Germany               32
# 6                Greece                8
# 7                 Italy               34
# 8           Netherlands               12
# 9                Poland               15
# 10             Portugal               22
# 11  Republic of Ireland                7
# 12               Russia                9
# 13                Spain               42
# 14               Sweden               17
# 15              Ukraine                7

# %%
euro_2012.Team
# Out:
# 0                 Croatia
# 1          Czech Republic
# 2                 Denmark
# 3                 England
# 4                  France
# 5                 Germany
# 6                  Greece
# 7                   Italy
# 8             Netherlands
# 9                  Poland
# 10               Portugal
# 11    Republic of Ireland
# 12                 Russia
# 13                  Spain
# 14                 Sweden
# 15                Ukraine
# Name: Team, dtype: object

# %% [markdown]
# ## ========================================================================

# %% [markdown]
# # Chapter - 5 Apply Function

# %%
student_details = pd.read_csv('student-mat.csv')
student_details
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
student_details['Medu'] = student_details['Medu'] + 2

# %%
student_details['Mjob'].
# Out:
# 0       at_home
# 1       at_home
# 2       at_home
# 3        health
# 4         other
#          ...
# 390    services
# 391    services
# 392       other
# 393    services
# 394       other
# Name: Mjob, Length: 395, dtype: object

# %%
student_details['Mjob'] = student_details['Mjob'].str.upper()
student_details
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     6     4   AT_HOME   teacher
# 1       GP   F   17       U     GT3       T     3     1   AT_HOME     other
# 2       GP   F   15       U     LE3       T     3     1   AT_HOME     other
# 3       GP   F   15       U     GT3       T     6     2    HEALTH  services
# 4       GP   F   16       U     GT3       T     5     3     OTHER     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     4     2  SERVICES  services
# 391     MS   M   17       U     LE3       T     5     1  SERVICES  services
# 392     MS   M   21       R     GT3       T     3     1     OTHER     other
# 393     MS   M   18       R     LE3       T     5     2  SERVICES     other
# 394     MS   M   19       U     LE3       T     3     1     OTHER   at_home
#
# ...

# %% [markdown]
# ## Check it Out:
#
# student_details[['Medu','Fedu']].apply(lambda x,y:x+y)

# %% [markdown]
# ## Quick Exercise
#
# **Create a new column with a name "Eligibility Criteria" where it returns True/1 if student age >=18 else False/0.**

# %%
student_details['Eligibility_Criteria'] = student_details['age'].apply(lambda x:1 if x>=18 else 0)

# %%
student_details
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     6     4   AT_HOME   teacher
# 1       GP   F   17       U     GT3       T     3     1   AT_HOME     other
# 2       GP   F   15       U     LE3       T     3     1   AT_HOME     other
# 3       GP   F   15       U     GT3       T     6     2    HEALTH  services
# 4       GP   F   16       U     GT3       T     5     3     OTHER     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     4     2  SERVICES  services
# 391     MS   M   17       U     LE3       T     5     1  SERVICES  services
# 392     MS   M   21       R     GT3       T     3     1     OTHER     other
# 393     MS   M   18       R     LE3       T     5     2  SERVICES     other
# 394     MS   M   19       U     LE3       T     3     1     OTHER   at_home
#
# ...

# %%
del student_details['Eligibility_Criteria']

# %%
student_details
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     6     4   AT_HOME   teacher
# 1       GP   F   17       U     GT3       T     3     1   AT_HOME     other
# 2       GP   F   15       U     LE3       T     3     1   AT_HOME     other
# 3       GP   F   15       U     GT3       T     6     2    HEALTH  services
# 4       GP   F   16       U     GT3       T     5     3     OTHER     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     4     2  SERVICES  services
# 391     MS   M   17       U     LE3       T     5     1  SERVICES  services
# 392     MS   M   21       R     GT3       T     3     1     OTHER     other
# 393     MS   M   18       R     LE3       T     5     2  SERVICES     other
# 394     MS   M   19       U     LE3       T     3     1     OTHER   at_home
#
# ...

# %%
def get_age(x):
    if x>=18:
        return 1
    else:
        return 0

# %%
student_details['Eligibility_Criteria'] = student_details['age'].apply(get_age)
student_details
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     6     4   AT_HOME   teacher
# 1       GP   F   17       U     GT3       T     3     1   AT_HOME     other
# 2       GP   F   15       U     LE3       T     3     1   AT_HOME     other
# 3       GP   F   15       U     GT3       T     6     2    HEALTH  services
# 4       GP   F   16       U     GT3       T     5     3     OTHER     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     4     2  SERVICES  services
# 391     MS   M   17       U     LE3       T     5     1  SERVICES  services
# 392     MS   M   21       R     GT3       T     3     1     OTHER     other
# 393     MS   M   18       R     LE3       T     5     2  SERVICES     other
# 394     MS   M   19       U     LE3       T     3     1     OTHER   at_home
#
# ...

# %% [markdown]
# # Chapter 6 - Creating Series and DataFrame
#
# Pandas has 2 DataStructures:
#
# 1. 1D - Series
# 2. 2D - DataFrame

# %%
vinay_scores = [96,99,98,100,100]
vinay_scores
# Out:
# [96, 99, 98, 100, 100]

# %%
type(vinay_scores)
# Out:
# list

# %%
data = pd.Series(data=[96,99,98,100,100])
data
# Out:
# 0     96
# 1     99
# 2     98
# 3    100
# 4    100
# dtype: int64

# %%
type(data)
# Out:
# pandas.core.series.Series

# %%
learner_details = pd.DataFrame(data={'fname':['Vinay','Gaurav'],
                                     'age'  :[22,23]})
learner_details
# Out:
#     fname  age
# 0   Vinay   22
# 1  Gaurav   23

# %%
type(learner_details)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## ========================================================================

# %% [markdown]
# # Chapter 7 - Concat | Append | Merge

# %%
sales_2017 = pd.read_csv('Sales Transactions-2017.csv')
sales_2017
# Out:
#              Date    Voucher               Party            Product  \
# 0        1/4/2017      Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017      Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017      Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017      Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017      Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...        ...                 ...                ...
# 47285  31/03/2018  Sal:10042                 Vkp        10*10 SHEET
# 47286         NaN        NaN                 NaN                NaN
# 47287         NaN        NaN                 NaN                NaN
# 47288         NaN    Total                   NaN                NaN
# 47289         NaN    Total                   NaN                NaN
#
#                 Qty          Rate           Gross        Disc  Voucher Amount
# ...

# %%
sales_2018 = pd.read_csv('Sales Transactions-2018.csv')
sales_2018
# Out:
#              Date   Voucher        Party            Product           Qty  \
# 0        1/4/2018   Sal:146         TP13  SILVER POUCH 9*12            50
# 1        1/4/2018   Sal:146         TP13             RUBBER             5
# 2        1/4/2018   Sal:146         TP13   DURGA 10*12 Blue      1,600.00
# 3        1/4/2018   Sal:146         TP13   DURGA 13*16 BLUE           400
# 4        1/4/2018   Sal:146         TP13    10*12 SARAS-NAT           600
# ...           ...       ...          ...                ...           ...
# 44735  31/03/2019  Sal:9610  HAMPI FOODS        SPOON SOOFY           200
# 44736         NaN       NaN          NaN                NaN           NaN
# 44737         NaN       NaN          NaN                NaN           NaN
# 44738         NaN   Total            NaN                NaN    666,056.00
# 44739         NaN   Total            NaN                NaN  7,097,803.00
#
#                 Rate           Gross        Disc  Voucher Amount
# ...

# %%
sales_2019 = pd.read_csv('Sales Transactions-2019.csv')
sales_2019
# Out:
#              Date   Voucher            Party         Product           Qty  \
# 0        1/4/2019   Sal:687  BALAJI PLASTICS   DONA-VAI-9100             1
# 1        1/4/2019   Sal:687  BALAJI PLASTICS  SMART BOUL(48)             1
# 2        1/4/2019   Sal:688  BALAJI PLASTICS      Vishnu Ice           110
# 3                                       28/3                             0
# 4        1/4/2019   Sal:689  BALAJI PLASTICS     100LEAF -SP             3
# ...           ...       ...              ...             ...           ...
# 19171  10/10/2019  Sal:4935        K.SRIHARI  13*16 WHITE RK           400
# 19172         NaN       NaN              NaN             NaN           NaN
# 19173         NaN       NaN              NaN             NaN           NaN
# 19174         NaN   Total                NaN             NaN     99,284.90
# 19175         NaN   Total                NaN             NaN  2,710,193.00
#
#                Rate          Gross        Disc Voucher Amount
# ...

# %%
complete_data = pd.concat([sales_2017,sales_2018,sales_2019])
complete_data
# Out:
#              Date   Voucher               Party            Product  \
# 0        1/4/2017     Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017     Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017     Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017     Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017     Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...       ...                 ...                ...
# 19171  10/10/2019  Sal:4935           K.SRIHARI     13*16 WHITE RK
# 19172         NaN       NaN                 NaN                NaN
# 19173         NaN       NaN                 NaN                NaN
# 19174         NaN   Total                   NaN                NaN
# 19175         NaN   Total                   NaN                NaN
#
#                 Qty          Rate          Gross        Disc Voucher Amount
# 0                 2      1,690.00       3,380.00         NaN      13,100.00
# ...

# %%
sales_2017.append([sales_2018,sales_2019])
# Out:
#              Date   Voucher               Party            Product  \
# 0        1/4/2017     Sal:1    SOLANKI PLASTICS      DONA-VAI-9100
# 1        1/4/2017     Sal:1    SOLANKI PLASTICS    LITE FOAM(1200)
# 2        1/4/2017     Sal:2  SARNESWARA TRADERS  VISHNU CHOTA WINE
# 3        1/4/2017     Sal:2  SARNESWARA TRADERS    LITE FOAM(1200)
# 4        1/4/2017     Sal:2  SARNESWARA TRADERS      DONA-VAI-9100
# ...           ...       ...                 ...                ...
# 19171  10/10/2019  Sal:4935           K.SRIHARI     13*16 WHITE RK
# 19172         NaN       NaN                 NaN                NaN
# 19173         NaN       NaN                 NaN                NaN
# 19174         NaN   Total                   NaN                NaN
# 19175         NaN   Total                   NaN                NaN
#
#                 Qty          Rate          Gross        Disc Voucher Amount
# 0                 2      1,690.00       3,380.00         NaN      13,100.00
# ...

# %%
complete_data.isna().sum()
# Out:
# Date               12591
# Voucher            12557
# Party                 40
# Product            12591
# Qty                12557
# Rate               12558
# Gross              12558
# Disc              105609
# Voucher Amount     83646
# dtype: int64

# %%
complete_data.dtypes
# Out:
# Date              object
# Voucher           object
# Party             object
# Product           object
# Qty               object
# Rate              object
# Gross             object
# Disc              object
# Voucher Amount    object
# dtype: object

# %%
complete_data.head(40)
# Out:
#         Date   Voucher                Party              Product       Qty  \
# 0   1/4/2017     Sal:1     SOLANKI PLASTICS        DONA-VAI-9100         2
# 1   1/4/2017     Sal:1     SOLANKI PLASTICS      LITE FOAM(1200)         6
# 2   1/4/2017     Sal:2   SARNESWARA TRADERS    VISHNU CHOTA WINE       500
# 3   1/4/2017     Sal:2   SARNESWARA TRADERS      LITE FOAM(1200)         6
# 4   1/4/2017     Sal:2   SARNESWARA TRADERS        DONA-VAI-9100         5
# 5   1/4/2017     Sal:2   SARNESWARA TRADERS   CLASSIC ENJOY(750)         1
# 6   1/4/2017   Sal:898                 Lock         Vishnu 250ml       100
# 7   1/4/2017   Sal:898                 Lock      BLACK DOG-350ML       100
# 8                       khader vali late en
# 9                                       try
# 10  1/4/2017  Sal:2497  VAMSI KRISHNA FANCY          Loose Items         1
# 11       NaN       NaN               #NAME?                  NaN       NaN
# 12                              DUMMY ENTRY
# ...

# %%
cleaned_data = pd.read_csv('Sales-Transactions-Edited.csv')
cleaned_data
# Out:
#             Date  Voucher               Party              Product  Qty  \
# 0       1/4/2017        1    SOLANKI PLASTICS        DONA-VAI-9100    2
# 1       1/4/2017        1    SOLANKI PLASTICS      LITE FOAM(1200)    6
# 2       1/4/2017        2  SARNESWARA TRADERS    VISHNU CHOTA WINE  500
# 3       1/4/2017        2  SARNESWARA TRADERS      LITE FOAM(1200)    6
# 4       1/4/2017        2  SARNESWARA TRADERS        DONA-VAI-9100    5
# ...          ...      ...                 ...                  ...  ...
# 95557  12/9/2019     4265                TP13        SPOON MED M.W   20
# 95558  12/9/2019     4266           K.SRIHARI       SMART BOUL(48)    1
# 95559  12/9/2019     4267                 SMS  SMARTBOUL GLA(4000)    1
# 95560  12/9/2019     4268           ANILFANCY         RR WINEGLASS  100
# 95561  12/9/2019     4268           ANILFANCY       RR WATER GLASS  100
#
#          Rate
# 0      1690.0
# 1      1620.0
# 2        23.0
# 3      1620.0
# 4      1690.0
# ...

# %%
cleaned_data.head(40)
# Out:
#         Date  Voucher                Party              Product   Qty     Rate
# 0   1/4/2017        1     SOLANKI PLASTICS        DONA-VAI-9100     2  1690.00
# 1   1/4/2017        1     SOLANKI PLASTICS      LITE FOAM(1200)     6  1620.00
# 2   1/4/2017        2   SARNESWARA TRADERS    VISHNU CHOTA WINE   500    23.00
# 3   1/4/2017        2   SARNESWARA TRADERS      LITE FOAM(1200)     6  1620.00
# 4   1/4/2017        2   SARNESWARA TRADERS        DONA-VAI-9100     5  1690.00
# 5   1/4/2017        2   SARNESWARA TRADERS   CLASSIC ENJOY(750)     1  1320.00
# 6   1/4/2017      898                 LOCK         VISHNU 250ML   100    30.00
# 7   1/4/2017      898                 LOCK      BLACK DOG-350ML   100    26.00
# 8   1/4/2017     2497  VAMSI KRISHNA FANCY          LOOSE ITEMS     1   800.00
# 9   1/4/2017     9263  VAMSI KRISHNA FANCY          LOOSE ITEMS     1   280.00
# 10  1/4/2017     9545                  VKP          LOOSE ITEMS     1   695.00
# ...

# %%
cleaned_data.isna().sum()
# Out:
# Date       0
# Voucher    0
# Party      0
# Product    0
# Qty        0
# Rate       1
# dtype: int64

# %%
cleaned_data.dtypes
# Out:
# Date        object
# Voucher      int64
# Party       object
# Product     object
# Qty          int64
# Rate       float64
# dtype: object

# %% [markdown]
# ## DAILY TASK - 5 Challenge to perform Data Cleaning
#
# ## DAILY TASK - 6 Explore Merge Function - Inner join, Outer join, Left join and Right join.

# %%
complete_data.shape
# Out:
# (111206, 9)

# %%
complete_data.to_csv('Cleaned_data.csv')

# %% [markdown]
# ## ========================================================================

# %% [markdown]
# # Chapter 8 - Grouping Vs Pivot Table Vs CrossTab

# %% [markdown]
# ## ========================================================================

# %% [markdown]
# ## CLUE to use GroupBy function
#
# ### Discrete Vs Continous Datatype:
#
# **Discrete** - Countable but not measurable(No units), cannot be seggregated.
#
# **Continous** - Measarable(Units), can be seggregated.

# %% [markdown]
# ## ========================================================================

# %%
insurance_details = pd.read_csv('insurance.csv')
insurance_details
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# ### 8.1 On an average, which region is getting more insurance charges?

# %%
insurance_details.groupby(by='region')['charges'].mean().sort_values(ascending = False).round()
# Out:
# region
# southeast    14735.0
# northeast    13406.0
# northwest    12418.0
# southwest    12347.0
# Name: charges, dtype: float64

# %% [markdown]
# ### 8.2 Which gender is getting more insurance charges on an average?

# %%
insurance_details.groupby(by = 'sex')['charges'].mean().round().sort_values(ascending = False)
# Out:
# sex
# male      13957.0
# female    12570.0
# Name: charges, dtype: float64

# %% [markdown]
# ### 8.3 Based on region and smokers, what is the average insurance charges?

# %%
insurance_details.groupby(by = ['smoker','region'])['charges'].mean().round()
# Out:
# smoker  region
# no      northeast     9166.0
#         northwest     8556.0
#         southeast     8032.0
#         southwest     8019.0
# yes     northeast    29674.0
#         northwest    30192.0
#         southeast    34845.0
#         southwest    32269.0
# Name: charges, dtype: float64

# %%
insurance_details.groupby(by = ['smoker','region','children'])['charges'].mean().round()
# Out:
# smoker  region     children
# no      northeast  0            8072.0
#                    1            9898.0
#                    2           11669.0
#                    3            7653.0
#                    4           14485.0
#                    5            6979.0
#         northwest  0            7545.0
#                    1            7982.0
#                    2            9951.0
#                    3           10548.0
#                    4            9322.0
#                    5            8966.0
#         southeast  0            7060.0
#                    1            8016.0
#                    2            7520.0
#                    3           11987.0
#                    4           14451.0
#                    5           10115.0
#         southwest  0            7754.0
#                    1            7647.0
#                    2            8947.0
#                    3            8650.0
#                    4            9282.0
# ...

# %%
pd.pivot_table(data = insurance_details,values='charges',index='region',columns=['smoker','children'], aggfunc='mean').round()
# Out:
# smoker         no                                                  yes  \
# children        0       1        2        3        4        5        0
# region
# northeast  8072.0  9898.0  11669.0   7653.0  14485.0   6979.0  28167.0
# northwest  7545.0  7982.0   9951.0  10548.0   9322.0   8966.0  28333.0
# southeast  7060.0  8016.0   7520.0  11987.0  14451.0  10115.0  35515.0
# southwest  7754.0  7647.0   8947.0   8650.0   9282.0   6933.0  30852.0
#
# smoker
# children         1        2        3        4        5
# region
# northeast  32340.0  22696.0  34004.0      NaN      NaN
# northwest  26470.0  31032.0  36160.0  21472.0      NaN
# southeast  32503.0  37619.0  32551.0      NaN      NaN
# southwest  34550.0  37569.0  21617.0  29062.0  19023.0

# %%
pd.pivot_table(data = insurance_details,values='charges',index='region',columns=['smoker'], aggfunc='mean').round().sort_values(by = 'yes',ascending = False)
# Out:
# smoker         no      yes
# region
# southeast  8032.0  34845.0
# southwest  8019.0  32269.0
# northwest  8556.0  30192.0
# northeast  9166.0  29674.0

# %% [markdown]
# ### 8.4 How many smokers are male and female?

# %%
insurance_details
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
pd.crosstab(index = insurance_details['sex'],columns = insurance_details['smoker'],margins=True)
# Out:
# smoker    no  yes   All
# sex
# female   547  115   662
# male     517  159   676
# All     1064  274  1338

# %%
insurance_details.shape
# Out:
# (1338, 7)

# %%
insurance_details.groupby('sex')['charges'].count()
# Out:
# sex
# female    662
# male      676
# Name: charges, dtype: int64

# %%
insurance_details['sex'].value_counts()
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %% [markdown]
# ### Quick Exercise

# %% [markdown]
# ### Use u.user file and come up with atleast 1 insight.

# %%
user_data = pd.read_csv('u.user',sep = '|')
user_data
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %% [markdown]
# ### How many people are working in each occupation?

# %%
user_data.groupby('occupation')['user_id'].count()
# Out:
# occupation
# administrator     79
# artist            28
# doctor             7
# educator          95
# engineer          67
# entertainment     18
# executive         32
# healthcare        16
# homemaker          7
# lawyer            12
# librarian         51
# marketing         26
# none               9
# other            105
# programmer        66
# retired           14
# salesman          12
# scientist         31
# student          196
# technician        27
# writer            45
# Name: user_id, dtype: int64

# %%
user_data['occupation'].value_counts()
# Out:
# student          196
# other            105
# educator          95
# administrator     79
# engineer          67
# programmer        66
# librarian         51
# writer            45
# executive         32
# scientist         31
# artist            28
# technician        27
# marketing         26
# entertainment     18
# healthcare        16
# retired           14
# lawyer            12
# salesman          12
# none               9
# doctor             7
# homemaker          7
# Name: occupation, dtype: int64

# %%
insurance_details.aggregate()

# %% [markdown]
# ### Explore Pandas Aggregation function.

# %% [markdown]
# # THE END!!
