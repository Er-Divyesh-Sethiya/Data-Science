# %% [markdown]
# # DATA PREPARATION/DATA PREPROCESSING
#
# ### 3 Step Approach:
#
# **Step 1: Data Cleaning - drop, dropna. Mean, Median, mode Imputation (or) Any Value Imputation for Nan Values.**
#
# **Step 2: Data Type Convertion(Optional)**
#
# **Step 3: Data Transformation**

# %% [markdown]
# # 1. Import Necessary libraries

# %%
import pandas as pd

# %% [markdown]
# # 2. Import Data

# %%
weather_data_2010 = pd.read_csv('data_clean.csv')
weather_data_2010
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# 5             6   28.0      NaN  14.9     66     5    6  2010    66       C
# 6             7   23.0    299.0   8.6     65     5    7  2010    65      PS
# 7             8   19.0     99.0  13.8     59     5    8  2010    59       C
# 8             9    8.0     19.0  20.1     61     5    9  2010    61      PS
# 9            10    NaN    194.0   8.6     69     5   10  2010    69       S
# 10           11    7.0      NaN   6.9      C     5   11  2010    74       C
# ...

# %% [markdown]
# # 3. Data Understanding

# %% [markdown]
# ## 3.1 Perform Initial Analysis

# %%
weather_data_2010.shape
# Out:
# (158, 10)

# %%
weather_data_2010.isna().sum()
# Out:
# Unnamed: 0     0
# Ozone         38
# Solar.R        7
# Wind           0
# Temp C         0
# Month          0
# Day            0
# Year           0
# Temp           0
# Weather        3
# dtype: int64

# %%
weather_data_2010.dtypes
# Out:
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Temp C         object
# Month          object
# Day             int64
# Year            int64
# Temp            int64
# Weather        object
# dtype: object

# %% [markdown]
# # 4. Data Preparation

# %% [markdown]
# ### Step 1: Data Cleaning

# %%
del weather_data_2010['Unnamed: 0']

# %%
weather_data_2010.head(40)
# Out:
#     Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0    41.0    190.0   7.4     67     5    1  2010    67       S
# 1    36.0    118.0   8.0     72     5    2  2010    72       C
# 2    12.0    149.0  12.6     74     5    3  2010    74      PS
# 3    18.0    313.0  11.5     62     5    4  2010    62       S
# 4     NaN      NaN  14.3     56     5    5  2010    56       S
# 5    28.0      NaN  14.9     66     5    6  2010    66       C
# 6    23.0    299.0   8.6     65     5    7  2010    65      PS
# 7    19.0     99.0  13.8     59     5    8  2010    59       C
# 8     8.0     19.0  20.1     61     5    9  2010    61      PS
# 9     NaN    194.0   8.6     69     5   10  2010    69       S
# 10    7.0      NaN   6.9      C     5   11  2010    74       C
# 11   16.0    256.0   9.7     69     5   12  2010    69      PS
# 12   11.0    290.0   9.2     66     5   13  2010    66       S
# 13   14.0    274.0  10.9     68     5   14  2010    68       S
# ...

# %%
weather_data_2010.isna().sum()
# Out:
# Ozone      38
# Solar.R     7
# Wind        0
# Temp C      0
# Month       0
# Day         0
# Year        0
# Temp        0
# Weather     3
# dtype: int64

# %%
38/158 * 100
# Out:
# 24.050632911392405

# %%
weather_data_2010['Ozone'].mean()
# Out:
# 41.583333333333336

# %%
weather_data_2010['Ozone'].median()
# Out:
# 30.5

# %% [markdown]
# ## Let's take Client, Abishek has approved to go with Median Imputation for Ozone feature.

# %%
weather_data_2010['Ozone'].fillna(value=30.5,inplace=True)

# %%
weather_data_2010.isna().sum()
# Out:
# Ozone      0
# Solar.R    7
# Wind       0
# Temp C     0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    3
# dtype: int64

# %%
weather_data_2010.head(40)
# Out:
#     Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0    41.0    190.0   7.4     67     5    1  2010    67       S
# 1    36.0    118.0   8.0     72     5    2  2010    72       C
# 2    12.0    149.0  12.6     74     5    3  2010    74      PS
# 3    18.0    313.0  11.5     62     5    4  2010    62       S
# 4    30.5      NaN  14.3     56     5    5  2010    56       S
# 5    28.0      NaN  14.9     66     5    6  2010    66       C
# 6    23.0    299.0   8.6     65     5    7  2010    65      PS
# 7    19.0     99.0  13.8     59     5    8  2010    59       C
# 8     8.0     19.0  20.1     61     5    9  2010    61      PS
# 9    30.5    194.0   8.6     69     5   10  2010    69       S
# 10    7.0      NaN   6.9      C     5   11  2010    74       C
# 11   16.0    256.0   9.7     69     5   12  2010    69      PS
# 12   11.0    290.0   9.2     66     5   13  2010    66       S
# 13   14.0    274.0  10.9     68     5   14  2010    68       S
# ...

# %%
weather_data_2010.isna().sum()
# Out:
# Ozone      0
# Solar.R    7
# Wind       0
# Temp C     0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    3
# dtype: int64

# %%
7/158
# Out:
# 0.04430379746835443

# %%
pd.set_option('max_rows',None)

# %%
weather_data_2010.head(158)
# Out:
#      Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4     67     5    1  2010    67       S
# 1     36.0    118.0   8.0     72     5    2  2010    72       C
# 2     12.0    149.0  12.6     74     5    3  2010    74      PS
# 3     18.0    313.0  11.5     62     5    4  2010    62       S
# 4     30.5      NaN  14.3     56     5    5  2010    56       S
# 5     28.0      NaN  14.9     66     5    6  2010    66       C
# 6     23.0    299.0   8.6     65     5    7  2010    65      PS
# 7     19.0     99.0  13.8     59     5    8  2010    59       C
# 8      8.0     19.0  20.1     61     5    9  2010    61      PS
# 9     30.5    194.0   8.6     69     5   10  2010    69       S
# 10     7.0      NaN   6.9      C     5   11  2010    74       C
# 11    16.0    256.0   9.7     69     5   12  2010    69      PS
# 12    11.0    290.0   9.2     66     5   13  2010    66       S
# 13    14.0    274.0  10.9     68     5   14  2010    68       S
# ...

# %% [markdown]
# ## Let's take client, Abishek Approved to drop the Null observations of Solar.R feature and Weather.

# %%
weather_data_2010.dropna(inplace=True)

# %%
weather_data_2010.isna().sum()
# Out:
# Ozone      0
# Solar.R    0
# Wind       0
# Temp C     0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    0
# dtype: int64

# %% [markdown]
# ### Step 2 - Data Type Convertion

# %%
weather_data_2010.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Temp C      object
# Month       object
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
del weather_data_2010['Temp C']

# %%
weather_data_2010.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Month       object
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
weather_data_2010.head(40)
# Out:
#     Ozone  Solar.R  Wind Month  Day  Year  Temp Weather
# 0    41.0    190.0   7.4     5    1  2010    67       S
# 1    36.0    118.0   8.0     5    2  2010    72       C
# 2    12.0    149.0  12.6     5    3  2010    74      PS
# 3    18.0    313.0  11.5     5    4  2010    62       S
# 6    23.0    299.0   8.6     5    7  2010    65      PS
# 7    19.0     99.0  13.8     5    8  2010    59       C
# 8     8.0     19.0  20.1     5    9  2010    61      PS
# 9    30.5    194.0   8.6     5   10  2010    69       S
# 11   16.0    256.0   9.7     5   12  2010    69      PS
# 12   11.0    290.0   9.2     5   13  2010    66       S
# 13   14.0    274.0  10.9     5   14  2010    68       S
# 14   18.0     65.0  13.2     5   15  2010    58       C
# 15   14.0    334.0  11.5     5   16  2010    64       S
# 16   34.0    307.0  12.0     5   17  2010    66       S
# 17    6.0     78.0  18.4     5   18  2010    57       C
# 18   30.0    322.0  11.5     5   19  2010    68      PS
# ...

# %%
weather_data_2010['Month'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-21c75e1e4262> in <module>
# ----> 1 weather_data_2010['Month'].astype('int')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# ...

# %%
weather_data_2010['Month'] =pd.to_numeric(weather_data_2010['Month'],errors='coerce',)#.astype('int')

# %%
weather_data_2010.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Month      float64
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
weather_data_2010.isna().sum()
# Out:
# Ozone      0
# Solar.R    0
# Wind       0
# Month      1
# Day        0
# Year       0
# Temp       0
# Weather    0
# dtype: int64

# %%
weather_data_2010['Month'].fillna(value=5,inplace=True)

# %%
weather_data_2010.isna().sum()
# Out:
# Ozone      0
# Solar.R    0
# Wind       0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    0
# dtype: int64

# %%
weather_data_2010.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Month      float64
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
weather_data_2010['Month'] = weather_data_2010['Month'].astype('int')

# %%
weather_data_2010
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4      5    1  2010    67       S
# 1     36.0    118.0   8.0      5    2  2010    72       C
# 2     12.0    149.0  12.6      5    3  2010    74      PS
# 3     18.0    313.0  11.5      5    4  2010    62       S
# 6     23.0    299.0   8.6      5    7  2010    65      PS
# 7     19.0     99.0  13.8      5    8  2010    59       C
# 8      8.0     19.0  20.1      5    9  2010    61      PS
# 9     30.5    194.0   8.6      5   10  2010    69       S
# 11    16.0    256.0   9.7      5   12  2010    69      PS
# 12    11.0    290.0   9.2      5   13  2010    66       S
# 13    14.0    274.0  10.9      5   14  2010    68       S
# 14    18.0     65.0  13.2      5   15  2010    58       C
# 15    14.0    334.0  11.5      5   16  2010    64       S
# 16    34.0    307.0  12.0      5   17  2010    66       S
# 17     6.0     78.0  18.4      5   18  2010    57       C
# ...

# %%
weather_data_2010.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Month        int32
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %% [markdown]
# ### Step 3: Data Transformation

# %% [markdown]
# ### 2 Transformation Techniques: Discrete Vs Continous
#
# **1. Discrete - Label Encoding/One Hot Encoding**
#
# **2. Continous - MinMax Scaler/Standard Scaler/Robust Scaler**

# %%
weather_data_2010
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4      5    1  2010    67       S
# 1     36.0    118.0   8.0      5    2  2010    72       C
# 2     12.0    149.0  12.6      5    3  2010    74      PS
# 3     18.0    313.0  11.5      5    4  2010    62       S
# 6     23.0    299.0   8.6      5    7  2010    65      PS
# 7     19.0     99.0  13.8      5    8  2010    59       C
# 8      8.0     19.0  20.1      5    9  2010    61      PS
# 9     30.5    194.0   8.6      5   10  2010    69       S
# 11    16.0    256.0   9.7      5   12  2010    69      PS
# 12    11.0    290.0   9.2      5   13  2010    66       S
# 13    14.0    274.0  10.9      5   14  2010    68       S
# 14    18.0     65.0  13.2      5   15  2010    58       C
# 15    14.0    334.0  11.5      5   16  2010    64       S
# 16    34.0    307.0  12.0      5   17  2010    66       S
# 17     6.0     78.0  18.4      5   18  2010    57       C
# ...

# %% [markdown]
# ### 1. Label Encoding

# %%
weather_data_2010_2 = weather_data_2010.copy()
weather_data_2010_2
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4      5    1  2010    67       S
# 1     36.0    118.0   8.0      5    2  2010    72       C
# 2     12.0    149.0  12.6      5    3  2010    74      PS
# 3     18.0    313.0  11.5      5    4  2010    62       S
# 6     23.0    299.0   8.6      5    7  2010    65      PS
# 7     19.0     99.0  13.8      5    8  2010    59       C
# 8      8.0     19.0  20.1      5    9  2010    61      PS
# 9     30.5    194.0   8.6      5   10  2010    69       S
# 11    16.0    256.0   9.7      5   12  2010    69      PS
# 12    11.0    290.0   9.2      5   13  2010    66       S
# 13    14.0    274.0  10.9      5   14  2010    68       S
# 14    18.0     65.0  13.2      5   15  2010    58       C
# 15    14.0    334.0  11.5      5   16  2010    64       S
# 16    34.0    307.0  12.0      5   17  2010    66       S
# 17     6.0     78.0  18.4      5   18  2010    57       C
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
weather_data_2010_2['Weather'] = le.fit_transform(weather_data_2010['Weather'])
weather_data_2010_2
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp  Weather
# 0     41.0    190.0   7.4      5    1  2010    67        2
# 1     36.0    118.0   8.0      5    2  2010    72        0
# 2     12.0    149.0  12.6      5    3  2010    74        1
# 3     18.0    313.0  11.5      5    4  2010    62        2
# 6     23.0    299.0   8.6      5    7  2010    65        1
# 7     19.0     99.0  13.8      5    8  2010    59        0
# 8      8.0     19.0  20.1      5    9  2010    61        1
# 9     30.5    194.0   8.6      5   10  2010    69        2
# 11    16.0    256.0   9.7      5   12  2010    69        1
# 12    11.0    290.0   9.2      5   13  2010    66        2
# 13    14.0    274.0  10.9      5   14  2010    68        2
# 14    18.0     65.0  13.2      5   15  2010    58        0
# 15    14.0    334.0  11.5      5   16  2010    64        2
# 16    34.0    307.0  12.0      5   17  2010    66        2
# 17     6.0     78.0  18.4      5   18  2010    57        0
# ...

# %%
weather_data_2010_3 = weather_data_2010.copy()
weather_data_2010_3
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4      5    1  2010    67       S
# 1     36.0    118.0   8.0      5    2  2010    72       C
# 2     12.0    149.0  12.6      5    3  2010    74      PS
# 3     18.0    313.0  11.5      5    4  2010    62       S
# 6     23.0    299.0   8.6      5    7  2010    65      PS
# 7     19.0     99.0  13.8      5    8  2010    59       C
# 8      8.0     19.0  20.1      5    9  2010    61      PS
# 9     30.5    194.0   8.6      5   10  2010    69       S
# 11    16.0    256.0   9.7      5   12  2010    69      PS
# 12    11.0    290.0   9.2      5   13  2010    66       S
# 13    14.0    274.0  10.9      5   14  2010    68       S
# 14    18.0     65.0  13.2      5   15  2010    58       C
# 15    14.0    334.0  11.5      5   16  2010    64       S
# 16    34.0    307.0  12.0      5   17  2010    66       S
# 17     6.0     78.0  18.4      5   18  2010    57       C
# ...

# %% [markdown]
# ### 2. One Hot Encoding
#
# It can be built by using 2 libraries:
#
# 1. sklearn - OneHotEncoder()
# 2. Pandas  - pd.get_dummies()

# %% [markdown]
# ### Using Sklearn

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder()
ohe.fit_transform(weather_data_2010_3['Weather'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-0ef314c3c566> in <module>
#       1 from sklearn.preprocessing import OneHotEncoder
#       2 ohe = OneHotEncoder()
# ----> 3 ohe.fit_transform(weather_data_2010_3['Weather'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py in fit_transform(self, X, y)
#     441         """
#     442         self._validate_keywords()
# --> 443         return super().fit_transform(X, y)
#     444
#     445     def transform(self, X):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
# ...

# %% [markdown]
# ### Using Pandas library

# %%
weather_data_2010_3 = pd.get_dummies(data = weather_data_2010_3,columns=['Weather'])
weather_data_2010_3
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp  Weather_C  Weather_PS  \
# 0     41.0    190.0   7.4      5    1  2010    67          0           0
# 1     36.0    118.0   8.0      5    2  2010    72          1           0
# 2     12.0    149.0  12.6      5    3  2010    74          0           1
# 3     18.0    313.0  11.5      5    4  2010    62          0           0
# 6     23.0    299.0   8.6      5    7  2010    65          0           1
# 7     19.0     99.0  13.8      5    8  2010    59          1           0
# 8      8.0     19.0  20.1      5    9  2010    61          0           1
# 9     30.5    194.0   8.6      5   10  2010    69          0           0
# 11    16.0    256.0   9.7      5   12  2010    69          0           1
# 12    11.0    290.0   9.2      5   13  2010    66          0           0
# 13    14.0    274.0  10.9      5   14  2010    68          0           0
# 14    18.0     65.0  13.2      5   15  2010    58          1           0
# ...

# %% [markdown]
# ## ========================================================================

# %% [markdown]
# # LABEL ENCODER VS ONE HOT ENCODER
#
# ### Input feature:
# Based on whether it is **Parametric or a Non Parametric Model**, we will choosing between LE or OHE.
# * For **Parametric Models** - better to go with **OHE.**
# * For **Non-Parametric Models** - always go with **Label Encoding.**
#
# ### Output feature:
# Always the output feature, it must be **Label Encoder.**

# %% [markdown]
# ## ========================================================================
